# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanusha-Shrivastava/First-project/blob/master/bones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import tensorflow as tf
import keras

from keras import backend as K
from keras import losses

from keras.models import Model, Sequential
from keras.objectives import categorical_crossentropy

from keras.layers import Input, concatenate
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, Conv2DTranspose, ZeroPadding2D

from keras.optimizers import Adam, Adadelta, Adamax, Nadam, Adagrad, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, Callback

from keras.initializers import RandomUniform, RandomNormal
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import time
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
# !pip install dicom
# Out:
# Collecting dicom
#   Downloading https://files.pythonhosted.org/packages/6c/0e/488becc361f1416f6682a9b9c223eb6a9db2d5d093fb46ea91c762eb6e4a/dicom-0.9.9.post1-py3-none-any.whl (766kB)
#      |████████████████████████████████| 768kB 3.3MB/s
# Installing collected packages: dicom
# Successfully installed dicom-0.9.9.post1

# %%
class PatientData(object):

    """
    
    PatientData looks for files of 3DIRCAD database.
    This database contains DICOM files and data is split into folders.
    PATIENT_DICOM folder contains original original CT Images
    MASKS_DICOM contains a list of several folders. Each folder is named
    according to the organ highlighted in the masks of the files within.
    During PatientData initialization, it will look for the folder pointed at
    root_dir and will load files named with same name on MASKS_DICOM/<organ name>/*
    
    """
    def __init__(self, root_dir, oi, file_extension=".dcm", split_part=0.5):

        import os, re
        patient_images = {}
        import pdb
        
        #iteration = 0
        for root, dirs, files in os.walk(root_dir):
          #for dir in dirs:
            
            for file in files:
                if file.endswith(file_extension):
                    
                    if 'PATIENT_DICOM' in root:
                        #pdb.set_trace()
                        if not patient_images.get(file,None):
                            patient_images[file] = {}
                        p = os.path.join(root,file)
                        patient_images[file]['real'] = p
                        #patient_images[file] = p
                    elif 'MASKS_DICOM' in root:
                        if not patient_images.get(file,None):
                            patient_images[file] = {}
                        p = os.path.join(root,file)
                        rs = re.match('.*MASKS_DICOM/(.*)/.*', str(p))
                        patient_images[file][rs.groups()[0]] = p
                    
                     '''During PatientData initialization, it will look for the folder pointed at
                        root_dir and will load files named with same name on MASKS_DICOM/<organ name>/*'''

        #print(iteration)
        #print(patient_images.keys())
        #print(patient_images.values())
        self.oi = oi
        self.X = []
        self.Y = []
        #pdb.set_trace()
        for k,v in patient_images.items():
            for k1,v1 in v.items():
                if k1 == self.oi:
                    if v.get('real'):
                      self.X.append(v['real'])
                      self.Y.append(v1)
        
        if len(self.X) != len(self.Y):
            raise Exception("number of input images (%d) does not match number of training samples (%d)" % 
                            (len(self.X),len(self.Y)))

        from random import shuffle
            
        self.train_limit = int(len(self.X)*split_part)
        self.indexes = list(range(len(self.X)))
        shuffle(self.indexes)            

        self.X1 = [self.X[c] for c in self.indexes]
        self.Y1 = [self.Y[c] for c in self.indexes]

        self.X1_train = self.X1[0:self.train_limit]
        self.X1_test = self.X1[self.train_limit:]          # 0->4, 1->1.dcm
        self.Y1_train = self.Y1[0:self.train_limit]
        self.Y1_test = self.Y1[self.train_limit:]          # 0->44, 1->11.dcm
        
        test_x_path = '/content/drive/My Drive/prediction_images/test_x/'
        test_y_path = '/content/drive/My Drive/prediction_images/test_y/'

        import os, shutil 

        for i in range(len(self.X1_test)):
            shutil.copyfile(self.X1_test[i], test_x_path+'test_x_'+str(i)+'.dcm')
            shutil.copyfile(self.Y1_test[i], test_y_path+'test_y_'+str(i)+'.dcm')
        

            
    def normalize(self, img):
        arr = img.copy().astype(np.float)
        M = np.float(np.max(img))
        if M != 0:
            arr *= 1./M
        #print("1")    
        
        #print(img)
        #print(arr)    
        return arr
    

    def add_gauss_noise(self, inp, expected_noise_ratio=0.05):
        image = inp.copy()
        if len(image.shape) == 2:
            row,col= image.shape
            ch = 1
        else:
            row,col,ch= image.shape
        mean = 0.
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col)) * expected_noise_ratio
        gauss = gauss.reshape(row,col)
        noisy = image + gauss
        return noisy

    def get_data(self, noisy=False, resize_side=None, verbose=False):
        from scipy.ndimage.interpolation import zoom        
        import dicom
        
        im_X = []
        im_Y = []
        for i in range(len(self.X)):
            img_x = dicom.read_file(self.X[i]).pixel_array
            img_y = dicom.read_file(self.Y[i]).pixel_array
            if resize_side != None:
                ratio = resize_side / 512.
                img_x = zoom(img_x, ratio).copy()
                img_y = zoom(img_y, ratio).copy()
            img_x = self.normalize(img_x)
            img_y = self.normalize(img_y)
            

            if np.sum(img_y) < 5.:
                if np.random.randint(1,10) <= 5:
                    if verbose:
                        print("discarding a very zero like image %s (%f)" % (self.Y[i],np.sum(img_y)))
                    continue
            if noisy:
                img_x = self.add_gauss_noise(img_x)
                img_y = self.add_gauss_noise(img_y)
            im_X.append(img_x)
            im_Y.append(img_y)
        
        shuffleX = [im_X[c] for c in self.indexes]
        shuffleY = [im_Y[c] for c in self.indexes]
        
        train_x = shuffleX[0:self.train_limit]
        test_x = shuffleX[self.train_limit:]
        train_y = shuffleY[0:self.train_limit]
        test_y = shuffleY[self.train_limit:]
    
        return train_x, train_y, test_x, test_y

# %%
root_dir = "/content/drive/My Drive/unet data"

# %%
sample_height, sample_width = (512,512)
output_width, output_height = (512, 512)
img_tot_size = sample_width*sample_height

# %%
pd = PatientData(root_dir, 'bone', split_part=0.8)

# %%
pd.X
# Out:
# ['/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_0a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_1a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_107a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_10a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_108a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_100a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_109a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_101a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_102a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_11a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_103a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_110a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_104a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_105a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_111a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_106a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_112a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_113a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_121a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_114a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_115a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_122a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_119a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_123a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_117a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_116a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_124a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_118a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_125a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_12a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_120a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_126a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_128a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_2a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_13a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_127a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_20a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_14a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_21a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_15a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_19a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_22a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_17a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_23a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_18a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_16a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_24a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_25a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_33a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_26a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_34a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_27a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_32a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_35a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_28a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_36a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_30a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_31a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_37a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_3a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_38a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_29a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_39a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_4a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_40a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_48a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_41a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_49a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_42a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_44a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_5a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_43a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_50a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_47a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_46a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_51a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_45a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_52a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_53a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_61a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_54a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_55a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_62a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_56a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_63a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_57a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_58a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_64a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_59a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_65a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_6a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_60a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_66a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_67a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_75a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_68a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_76a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_69a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_7a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_77a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_71a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_78a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_70a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_72a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_79a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_73a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_8a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_74a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_80a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_81a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_82a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_9a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_83a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_90a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_84a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_85a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_91a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_86a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_92a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_87a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_93a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_88a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_89a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_94a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_95a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_96a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_97a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_98a.dcm',
#  '/content/drive/My Drive/unet data/3dcardb1.1/PATIENT_DICOM/image_99a.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_1i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_100i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_10i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_0i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_101i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_103i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_102i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_104i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_105i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_107i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_108i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_106i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_109i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_110i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_11i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_12i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_13i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_15i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_14i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_16i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_17i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_18i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_19i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_2i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_20i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_21i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_22i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_23i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_24i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_25i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_26i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_27i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_28i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_29i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_3i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_30i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_31i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_32i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_33i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_34i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_35i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_37i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_36i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_38i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_39i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_4i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_40i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_41i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_42i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_44i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_45i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_43i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_46i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_48i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_47i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_49i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_5i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_50i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_51i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_52i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_53i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_55i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_54i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_56i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_57i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_58i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_59i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_6i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_61i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_60i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_63i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_62i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_64i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_65i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_67i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_66i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_69i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_68i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_7i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_70i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_72i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_71i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_73i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_74i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_75i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_76i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_78i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_77i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_79i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_8i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_80i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_82i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_81i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_83i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_84i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_86i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_85i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_87i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_89i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_88i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_9i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_90i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_91i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_92i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_93i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_94i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_96i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_95i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_97i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_98i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.9/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_99i.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_10j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_100j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_0j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_1j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_101j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_103j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_102j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_104j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_106j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_105j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_107j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_108j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_109j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_110j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_11j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_111j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_112j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_113j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_114j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_115j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_116j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_117j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_118j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_119j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_12j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_121j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_120j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_13j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_14j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_15j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_16j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_17j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_21j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_22j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_23j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_24j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_25j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_26j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_27j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_28j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_29j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_3j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_30j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_31j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_32j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_33j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_34j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_35j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_36j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_37j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_38j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_39j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_4j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_40j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_41j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_42j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_43j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_44j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_45j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_46j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_47j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_48j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_49j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_5j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_50j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_51j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_52j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_53j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_54j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_55j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_56j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_57j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_58j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_59j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_6j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_60j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_61j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_62j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_63j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_64j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_65j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_66j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_67j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_68j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_69j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_7j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_70j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_71j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_72j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_73j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_74j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_75j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_77j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_76j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_78j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_79j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_80j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_81j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_8j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_82j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_83j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_84j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_85j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_86j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_87j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_88j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_89j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_9j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_90j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_91j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_92j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_93j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_94j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_95j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_96j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_99j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_97j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_98j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_2j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_18j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_19j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.10/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_20j.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_0k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_10k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_100k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_1k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_101k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_103k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_102k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_104k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_105k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_106k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_107k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_108k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_109k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_110k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_11k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_111k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_112k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_113k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_114k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_115k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_116k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_117k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_118k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_119k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_12k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_121k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_120k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_122k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_123k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_125k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_124k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_126k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_127k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_128k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_129k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_13k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_130k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_131k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_14k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_15k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_16k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_18k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_17k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_19k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_2k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_20k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_21k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_22k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_23k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_25k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_24k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_26k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_27k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_29k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_28k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_3k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_30k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_32k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_31k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_33k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_34k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_35k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_36k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_37k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_38k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_4k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_39k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_40k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_41k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_42k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_43k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_44k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_45k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_46k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_47k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_48k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_49k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_5k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_50k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_51k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_52k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_54k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_53k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_55k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_59k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_58k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_56k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_57k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_6k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_60k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_62k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_61k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_63k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_64k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_65k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_66k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_67k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_68k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_69k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_7k.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.11/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_70k.dcm',
# ...
#  '/content/drive/My Drive/unet data/3Dircadb1.14/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_86n.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.14/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_93n.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.14/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_94n.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.14/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_95n.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.14/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_96n.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.14/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_98n.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.14/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_97n.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.14/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_99n.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_100o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_1o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_10o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_0o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_101o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_102o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_103o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_104o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_105o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_106o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_107o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_108o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_109o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_11o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_110o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_111o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_112o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_113o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_114o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_115o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_116o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_117o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_118o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_119o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_12o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_120o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_122o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_121o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_123o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_124o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_13o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_14o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_16o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_15o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_17o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_18o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_19o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_2o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_20o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_21o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_22o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_23o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_24o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_25o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_27o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_26o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_28o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_29o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_3o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_30o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_31o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_32o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_33o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_34o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_35o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_36o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_37o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_39o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_38o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_4o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_40o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_42o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_41o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_43o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_44o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_45o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_46o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_47o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_48o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_49o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_5o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_50o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_51o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_52o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_53o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_55o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_54o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_56o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_57o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_58o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_59o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_6o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_61o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_60o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_62o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_63o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_64o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_65o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_66o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_67o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_68o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_69o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_7o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_71o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_70o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_72o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_75o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_74o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_73o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_76o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_77o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_79o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_78o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_8o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_80o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_81o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_82o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_83o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_84o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_85o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_86o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_87o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_88o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_89o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_9o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_90o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_91o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_92o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_93o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_94o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_95o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_96o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_97o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_99o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.15/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_98o.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.16/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_100p.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.16/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_10p.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.16/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_1p.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.16/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_0p.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.16/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_101p.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.16/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_102p.dcm',
#  '/content/drive/My Drive/unet data/3Dircadb1.16/PATIENT_DICOM.zip (Unzipped Files)/PATIENT_DICOM/image_103p.dcm',
#  ...]

# %%
len(pd.X)
# Out:
# 2324

# %%
#pd.X = pd.X[0:10]
#pd.Y = pd.Y[0:10]

# %%
data = pd.get_data(False, sample_width) # Using 80% for training
train_x, train_y, test_x, test_y = map(np.array, data)
print("Using %s images for training and %s images for testing" % (len(train_x), len(test_x)))

# %%
lines = min(4,len(train_x)) # len(imgs_mask_test) #16
fig, axarr = plt.subplots(lines, 2, figsize=(15,15), sharex=True, sharey=False)

tot_dice = 0.
for i in range(0,lines):
    
    axarr[i,0].imshow(train_x[i].reshape(output_width, output_height), cmap='gray')
    axarr[i,1].imshow(train_y[i].reshape(output_width, output_height), cmap='gray')
    
    for x in range(2):
        axarr[i,x].axis('off')

fig.tight_layout()
fig.subplots_adjust(top=0.975)
plt.show()

# %%
train_x = np.array([t.reshape(sample_width, sample_height,1) for t in train_x])
train_y = np.array([t.reshape(sample_width, sample_height,1) for t in train_y])
test_x  = np.array([t.reshape(sample_width, sample_height,1) for t in test_x])
test_y  = np.array([t.reshape(sample_width, sample_height,1) for t in test_y])

# %%
def get_model(optimizer, loss_metric, metrics, lr=1e-3):
    inputs = Input((sample_width, sample_height, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    drop1 = Dropout(0.5)(pool1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(drop1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    drop2 = Dropout(0.5)(pool2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(drop2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    drop3 = Dropout(0.3)(pool3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(drop3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    drop4 = Dropout(0.3)(pool4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(drop4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

    # working with dice and adam
    model.compile(optimizer=Adam(lr=1e-3, decay=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
    
    #Adamax
    #model.compile(optimizer=Adamax(lr=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
    
    #SGD
    #model.compile(optimizer=SGD(lr=1e-2, momentum=0.8), loss=dice_coef_loss, metrics=[dice_coef])
    
    #Nadam
    #model.compile(optimizer=Nadam(lr=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
    
    #Adadelta
    #model.compile(optimizer=Nadam(lr=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
    
    return model

# %%
smooth = 1.

# Dice Coefficient to work with Tensorflow
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# Dice Coefficient to work outside Tensorflow
def dice_coef_2(y_true, y_pred):
    side = len(y_true[0])
    y_true_f = y_true.reshape(side*side)
    y_pred_f = y_pred.reshape(side*side)
    intersection = sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (sum(y_true_f) + sum(y_pred_f) + smooth)

# %%
model = get_model(optimizer=Adam, loss_metric=dice_coef_loss, metrics=[dice_coef], lr=1e-3)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
observe_var = 'dice_coef'
strategy = 'max'

# %%
start_time = time.time()

history = model.fit(train_x, train_y, batch_size=16,
          epochs=100, verbose=1, shuffle=True, validation_data=(test_x,test_y))


elapsed_time = time.time() - start_time
print("Elapsed time: ", elapsed_time)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 1859 samples, validate on 465 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1859/1859 [==============================] - 95s 51ms/step - loss: -0.6453 - dice_coef: 0.6453 - val_loss: -0.8026 - val_dice_coef: 0.8026
# Epoch 2/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.8555 - dice_coef: 0.8555 - val_loss: -0.8379 - val_dice_coef: 0.8379
# Epoch 3/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.8702 - dice_coef: 0.8702 - val_loss: -0.8706 - val_dice_coef: 0.8706
# Epoch 4/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.8834 - dice_coef: 0.8834 - val_loss: -0.8773 - val_dice_coef: 0.8773
# Epoch 5/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.8865 - dice_coef: 0.8865 - val_loss: -0.8850 - val_dice_coef: 0.8850
# Epoch 6/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.8928 - dice_coef: 0.8928 - val_loss: -0.8893 - val_dice_coef: 0.8893
# Epoch 7/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.8978 - dice_coef: 0.8978 - val_loss: -0.8846 - val_dice_coef: 0.8846
# Epoch 8/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9015 - dice_coef: 0.9015 - val_loss: -0.8920 - val_dice_coef: 0.8920
# Epoch 9/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9012 - dice_coef: 0.9012 - val_loss: -0.8988 - val_dice_coef: 0.8988
# Epoch 10/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9093 - dice_coef: 0.9093 - val_loss: -0.9086 - val_dice_coef: 0.9086
# Epoch 11/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9158 - dice_coef: 0.9158 - val_loss: -0.9127 - val_dice_coef: 0.9127
# Epoch 12/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9198 - dice_coef: 0.9198 - val_loss: -0.9179 - val_dice_coef: 0.9179
# Epoch 13/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9229 - dice_coef: 0.9229 - val_loss: -0.9196 - val_dice_coef: 0.9196
# Epoch 14/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9258 - dice_coef: 0.9258 - val_loss: -0.9216 - val_dice_coef: 0.9216
# Epoch 15/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9299 - dice_coef: 0.9299 - val_loss: -0.9284 - val_dice_coef: 0.9284
# Epoch 16/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9305 - dice_coef: 0.9305 - val_loss: -0.9232 - val_dice_coef: 0.9232
# Epoch 17/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9320 - dice_coef: 0.9320 - val_loss: -0.9281 - val_dice_coef: 0.9281
# Epoch 18/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9358 - dice_coef: 0.9358 - val_loss: -0.9205 - val_dice_coef: 0.9205
# Epoch 19/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9374 - dice_coef: 0.9374 - val_loss: -0.9267 - val_dice_coef: 0.9267
# Epoch 20/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9387 - dice_coef: 0.9387 - val_loss: -0.9322 - val_dice_coef: 0.9322
# Epoch 21/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9404 - dice_coef: 0.9404 - val_loss: -0.9276 - val_dice_coef: 0.9276
# Epoch 22/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9414 - dice_coef: 0.9414 - val_loss: -0.9317 - val_dice_coef: 0.9317
# Epoch 23/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9440 - dice_coef: 0.9440 - val_loss: -0.9313 - val_dice_coef: 0.9313
# Epoch 24/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9452 - dice_coef: 0.9452 - val_loss: -0.9274 - val_dice_coef: 0.9274
# Epoch 25/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9451 - dice_coef: 0.9451 - val_loss: -0.9315 - val_dice_coef: 0.9315
# Epoch 26/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9477 - dice_coef: 0.9477 - val_loss: -0.9317 - val_dice_coef: 0.9317
# Epoch 27/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9498 - dice_coef: 0.9498 - val_loss: -0.9358 - val_dice_coef: 0.9358
# Epoch 28/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9515 - dice_coef: 0.9515 - val_loss: -0.9329 - val_dice_coef: 0.9329
# Epoch 29/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9512 - dice_coef: 0.9512 - val_loss: -0.9381 - val_dice_coef: 0.9381
# Epoch 30/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9528 - dice_coef: 0.9528 - val_loss: -0.9317 - val_dice_coef: 0.9317
# Epoch 31/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9524 - dice_coef: 0.9524 - val_loss: -0.9349 - val_dice_coef: 0.9349
# Epoch 32/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9544 - dice_coef: 0.9544 - val_loss: -0.9347 - val_dice_coef: 0.9347
# Epoch 33/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9554 - dice_coef: 0.9554 - val_loss: -0.9317 - val_dice_coef: 0.9317
# Epoch 34/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9564 - dice_coef: 0.9564 - val_loss: -0.9373 - val_dice_coef: 0.9373
# Epoch 35/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9557 - dice_coef: 0.9557 - val_loss: -0.9354 - val_dice_coef: 0.9354
# Epoch 36/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9574 - dice_coef: 0.9574 - val_loss: -0.9372 - val_dice_coef: 0.9372
# Epoch 37/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9584 - dice_coef: 0.9584 - val_loss: -0.9347 - val_dice_coef: 0.9347
# Epoch 38/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9588 - dice_coef: 0.9588 - val_loss: -0.9411 - val_dice_coef: 0.9411
# Epoch 39/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9592 - dice_coef: 0.9592 - val_loss: -0.9405 - val_dice_coef: 0.9405
# Epoch 40/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9599 - dice_coef: 0.9599 - val_loss: -0.9354 - val_dice_coef: 0.9354
# Epoch 41/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9609 - dice_coef: 0.9609 - val_loss: -0.9391 - val_dice_coef: 0.9391
# Epoch 42/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9599 - dice_coef: 0.9599 - val_loss: -0.9351 - val_dice_coef: 0.9351
# Epoch 43/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9607 - dice_coef: 0.9607 - val_loss: -0.9407 - val_dice_coef: 0.9407
# Epoch 44/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9619 - dice_coef: 0.9619 - val_loss: -0.9418 - val_dice_coef: 0.9418
# Epoch 45/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9619 - dice_coef: 0.9619 - val_loss: -0.9370 - val_dice_coef: 0.9370
# Epoch 46/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9622 - dice_coef: 0.9622 - val_loss: -0.9350 - val_dice_coef: 0.9350
# Epoch 47/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9633 - dice_coef: 0.9633 - val_loss: -0.9360 - val_dice_coef: 0.9360
# Epoch 48/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9630 - dice_coef: 0.9630 - val_loss: -0.9410 - val_dice_coef: 0.9410
# Epoch 49/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9645 - dice_coef: 0.9645 - val_loss: -0.9384 - val_dice_coef: 0.9384
# Epoch 50/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9640 - dice_coef: 0.9640 - val_loss: -0.9348 - val_dice_coef: 0.9348
# Epoch 51/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9640 - dice_coef: 0.9640 - val_loss: -0.9382 - val_dice_coef: 0.9382
# Epoch 52/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9647 - dice_coef: 0.9647 - val_loss: -0.9425 - val_dice_coef: 0.9425
# Epoch 53/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9653 - dice_coef: 0.9653 - val_loss: -0.9403 - val_dice_coef: 0.9403
# Epoch 54/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9658 - dice_coef: 0.9658 - val_loss: -0.9390 - val_dice_coef: 0.9390
# Epoch 55/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9664 - dice_coef: 0.9664 - val_loss: -0.9395 - val_dice_coef: 0.9395
# Epoch 56/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9663 - dice_coef: 0.9663 - val_loss: -0.9371 - val_dice_coef: 0.9371
# Epoch 57/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9661 - dice_coef: 0.9661 - val_loss: -0.9375 - val_dice_coef: 0.9375
# Epoch 58/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9667 - dice_coef: 0.9667 - val_loss: -0.9406 - val_dice_coef: 0.9406
# Epoch 59/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9670 - dice_coef: 0.9670 - val_loss: -0.9363 - val_dice_coef: 0.9363
# Epoch 60/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9671 - dice_coef: 0.9671 - val_loss: -0.9387 - val_dice_coef: 0.9387
# Epoch 61/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9679 - dice_coef: 0.9679 - val_loss: -0.9359 - val_dice_coef: 0.9359
# Epoch 62/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9680 - dice_coef: 0.9680 - val_loss: -0.9374 - val_dice_coef: 0.9374
# Epoch 63/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9684 - dice_coef: 0.9684 - val_loss: -0.9386 - val_dice_coef: 0.9386
# Epoch 64/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9689 - dice_coef: 0.9689 - val_loss: -0.9335 - val_dice_coef: 0.9335
# Epoch 65/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9685 - dice_coef: 0.9685 - val_loss: -0.9346 - val_dice_coef: 0.9346
# Epoch 66/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9691 - dice_coef: 0.9691 - val_loss: -0.9351 - val_dice_coef: 0.9351
# Epoch 67/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9687 - dice_coef: 0.9687 - val_loss: -0.9345 - val_dice_coef: 0.9345
# Epoch 68/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9694 - dice_coef: 0.9694 - val_loss: -0.9366 - val_dice_coef: 0.9366
# Epoch 69/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9700 - dice_coef: 0.9700 - val_loss: -0.9345 - val_dice_coef: 0.9345
# Epoch 70/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9702 - dice_coef: 0.9702 - val_loss: -0.9297 - val_dice_coef: 0.9297
# Epoch 71/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9698 - dice_coef: 0.9698 - val_loss: -0.9385 - val_dice_coef: 0.9385
# Epoch 72/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9702 - dice_coef: 0.9702 - val_loss: -0.9339 - val_dice_coef: 0.9339
# Epoch 73/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9706 - dice_coef: 0.9706 - val_loss: -0.9335 - val_dice_coef: 0.9335
# Epoch 74/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9707 - dice_coef: 0.9707 - val_loss: -0.9302 - val_dice_coef: 0.9302
# Epoch 75/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9705 - dice_coef: 0.9705 - val_loss: -0.9339 - val_dice_coef: 0.9339
# Epoch 76/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9706 - dice_coef: 0.9706 - val_loss: -0.9375 - val_dice_coef: 0.9375
# Epoch 77/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9709 - dice_coef: 0.9709 - val_loss: -0.9376 - val_dice_coef: 0.9376
# Epoch 78/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9713 - dice_coef: 0.9713 - val_loss: -0.9346 - val_dice_coef: 0.9346
# Epoch 79/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9713 - dice_coef: 0.9713 - val_loss: -0.9318 - val_dice_coef: 0.9318
# Epoch 80/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9717 - dice_coef: 0.9717 - val_loss: -0.9329 - val_dice_coef: 0.9329
# Epoch 81/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9715 - dice_coef: 0.9715 - val_loss: -0.9347 - val_dice_coef: 0.9347
# Epoch 82/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9720 - dice_coef: 0.9720 - val_loss: -0.9357 - val_dice_coef: 0.9357
# Epoch 83/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9722 - dice_coef: 0.9722 - val_loss: -0.9377 - val_dice_coef: 0.9377
# Epoch 84/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9721 - dice_coef: 0.9721 - val_loss: -0.9332 - val_dice_coef: 0.9332
# Epoch 85/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9724 - dice_coef: 0.9724 - val_loss: -0.9311 - val_dice_coef: 0.9311
# Epoch 86/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9719 - dice_coef: 0.9719 - val_loss: -0.9323 - val_dice_coef: 0.9323
# Epoch 87/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9723 - dice_coef: 0.9723 - val_loss: -0.9364 - val_dice_coef: 0.9364
# Epoch 88/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9727 - dice_coef: 0.9727 - val_loss: -0.9362 - val_dice_coef: 0.9362
# Epoch 89/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9728 - dice_coef: 0.9728 - val_loss: -0.9320 - val_dice_coef: 0.9320
# Epoch 90/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9727 - dice_coef: 0.9727 - val_loss: -0.9340 - val_dice_coef: 0.9340
# Epoch 91/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9732 - dice_coef: 0.9732 - val_loss: -0.9331 - val_dice_coef: 0.9331
# Epoch 92/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9732 - dice_coef: 0.9732 - val_loss: -0.9322 - val_dice_coef: 0.9322
# Epoch 93/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9733 - dice_coef: 0.9733 - val_loss: -0.9294 - val_dice_coef: 0.9294
# Epoch 94/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9735 - dice_coef: 0.9735 - val_loss: -0.9313 - val_dice_coef: 0.9313
# Epoch 95/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9736 - dice_coef: 0.9736 - val_loss: -0.9356 - val_dice_coef: 0.9356
# Epoch 96/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9736 - dice_coef: 0.9736 - val_loss: -0.9312 - val_dice_coef: 0.9312
# Epoch 97/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9737 - dice_coef: 0.9737 - val_loss: -0.9250 - val_dice_coef: 0.9250
# Epoch 98/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9736 - dice_coef: 0.9736 - val_loss: -0.9185 - val_dice_coef: 0.9185
# Epoch 99/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9740 - dice_coef: 0.9740 - val_loss: -0.9326 - val_dice_coef: 0.9326
# Epoch 100/100
# 1859/1859 [==============================] - 75s 40ms/step - loss: -0.9740 - dice_coef: 0.9740 - val_loss: -0.9314 - val_dice_coef: 0.9314
# Elapsed time:  7502.301766395569

# %%
model_save_name = 'classifier_final1.pt'
path = F"/content/drive/My Drive/{model_save_name}"
model.save_weights(path)

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_dice_coef', 'loss', 'dice_coef'])

# %%
plt.plot(history.history['dice_coef'])
plt.title('Model Accuracy')
plt.ylabel('Dice Coef.')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['dice_coef'])
plt.title('Model Accuracy')
plt.ylabel('Dice Coef.')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
imgs_mask_test = model.predict(test_x, verbose=1)

tot_dice = 0.
dices = []
for i in range(len(imgs_mask_test)):
    r = dice_coef_2(test_y[i],imgs_mask_test[i])
    dices.append(r)
    tot_dice += r
    
avg_dice = tot_dice/float(len(imgs_mask_test))
print(avg_dice)
# Out:
# 465/465 [==============================] - 9s 20ms/step
# 0.9258228555026184

# %%
postProcess = True
if postProcess:        
    avg = np.average(imgs_mask_test)
    for k in range(len(imgs_mask_test)):
        im = imgs_mask_test[k]
        m = np.max(im)
        for i in range(len(im)):
            for j in range(len(im[i])):
                # remove low confidence results helps to increase dice result
                if im[i,j] < (0.5):
                    im[i,j] = 0.
    
    tot_dice = 0.
    dices = []
    for i in range(len(imgs_mask_test)):
        r = dice_coef_2(test_y[i],imgs_mask_test[i])
        dices.append(r)
        tot_dice += r
        

    avg_dice = tot_dice/float(len(imgs_mask_test))
    print(avg_dice)
# Out:
# 0.9259018055501481

# %%
fig, axarr = plt.subplots(3, 3, figsize=(20,20), sharex=True, sharey=False)

output_width, output_height = (512, 512)
for i in range(0,3):
    axarr[i,0].imshow(test_x[i].reshape(output_width, output_height), cmap='gray')
    axarr[i,1].imshow(test_y[i].reshape(output_width, output_height), cmap='gray')
    axarr[i,2].imshow(imgs_mask_test[i].reshape(output_width, output_height), cmap='gray')
    axarr[i,2].set_title('Dice Coef = ' + str(dices[i]),fontsize=45,ha='center')
    
    for x in range(3):
        axarr[i,x].axis('off')

fig.suptitle('Dice average = ' + str(avg_dice) ,fontsize=60)
fig.tight_layout()
fig.subplots_adjust(top=0.975)
plt.show()
